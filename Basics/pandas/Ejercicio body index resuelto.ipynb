# %% [markdown]
# https://www.kaggle.com/yersever/500-person-gender-height-weight-bodymassindex

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Cargar la librería pandas con el alias "pd" y  seaborn con alisas "sns"

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## 2. Leer el archivo body_index.csv usando pandas

# %%
df = pd.read_csv("datos/body_index.csv")

# %% [markdown]
# ## 3. Mostrar los primeros 5 registros.
# y los primeros 10?

# %%
df.head() # df.head(10)
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %% [markdown]
# ## Index:
# * 0 - Extremely Weak
# * 1 - Weak
# * 2 - Normal
# * 3 - Overweight
# * 4 - Obesity
# * 5 - Extreme Obesity

# %% [markdown]
# ## 4. Cuantos registros hay?

# %%
df.shape
# Out:
# (500, 4)

# %% [markdown]
# ## 5. Cuantos hombres hay? Y cuantas mujeres?

# %%
cantidad_hombres = len(df[df["Gender"] == "Male"])
cantidad_mujeres = len(df[df["Gender"] == "Female"])
print(f"Hay {cantidad_hombres} hombres y {cantidad_mujeres} mujeres")
# Out:
# Hay 245 hombres y 255 mujeres

# %% [markdown]
# ## 6. Cual es la media de las alturas?

# %%
media_altura = df["Height"].mean()
print(media_altura)
# Out:
# 169.944

# %% [markdown]
# ## 7. Cual es la mediana de los pesos?

# %%
mediana_pesos = df["Weight"].median()
print(mediana_pesos)
# Out:
# 106.0

# %% [markdown]
# ## 8. Cual es la moda de los indices?

# %%
moda_indices = df["Index"].mode().values[0]
print(moda_indices)
# Out:
# 5

# %% [markdown]
# ## 9. Mostrar el registro de la persona mas pesada

# %%
df.iloc[df['Weight'].idxmax()]
# Out:
# Gender    Male
# Height     166
# Weight     160
# Index        5
# Name: 106, dtype: object

# %% [markdown]
# ## 10. Graficar en barras la cuenta de los indices

# %%
ax = sns.countplot(x="Index", data=df)

# %% [markdown]
# ## 11. Graficar un scatterplot de altura vs pesos

# %%
ax = sns.scatterplot(x="Height", y="Weight", data=df)

# %% [markdown]
# ## 12. Al grafico anterior darle un color a cada clasificacion de body index

# %%
plt.figure(figsize=(7, 7))
sns.scatterplot(x="Height", y="Weight", hue="Index", data=df, palette="Set3")
plt.show()
